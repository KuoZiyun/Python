# %% [markdown]
# <a href="https://colab.research.google.com/github/KuoZiyun/Python/blob/main/Python%E4%BD%9C%E6%A5%AD4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
params = {
    'tickers':['2330.TW','2303.TW','2454.TW','2317.TW','2337.TW'],
    'start':'2025-01-01',
    'end':'2025-11-11',
    'interval':'1d'
}

# %%
# !pip install yfinance

# %%
import yfinance as yf
data = yf.download(**params)
data.tail()
# Out:
# /tmp/ipython-input-1577927734.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(**params)
# [*********************100%***********************]  5 of 5 completed
# Price           Close                                          High          \
# Ticker        2303.TW 2317.TW 2330.TW    2337.TW 2454.TW    2303.TW 2317.TW
# Date
# 2025-11-04  47.400002   244.0  1505.0  29.700001  1315.0  48.750000   255.0
# 2025-11-05  47.099998   247.0  1460.0  31.350000  1330.0  47.099998   248.5
# 2025-11-06  45.799999   248.0  1465.0  34.450001  1290.0  47.750000   250.5
# 2025-11-07  45.000000   244.0  1460.0  35.250000  1260.0  45.599998   250.5
# 2025-11-10  45.200001   249.5  1475.0  37.900002  1250.0  45.650002   250.0
#
# Price                                  ...       Open                  \
# Ticker     2330.TW    2337.TW 2454.TW  ...    2303.TW 2317.TW 2330.TW
# Date                                   ...
# ...

# %%
name_map = {'2330.TW': '台積電',
            '2303.TW': '聯電',
            '2454.TW': '聯發科',
            '2317.TW': '鴻海',
            '2337.TW': '旺宏'}

# %%
sector = {'2330.TW':'半導體',
          '2303.TW':'半導體',
          '2454.TW':'半導體',
          '2317.TW':'電子代工',
          '2337.TW':'半導體'}

# %%
import pandas as pd
df = pd.DataFrame({'tickers':['2330.TW','2303.TW','2454.TW','2317.TW','2337.TW']})
df['中文名'] = df['tickers'].map(name_map)
df['產業'] = df['tickers'].map(sector)
df
# Out:
#    tickers  中文名    產業
# 0  2330.TW  台積電   半導體
# 1  2303.TW   聯電   半導體
# 2  2454.TW  聯發科   半導體
# 3  2317.TW   鴻海  電子代工
# 4  2337.TW   旺宏   半導體

# %%
default_paramas = {'start':'2025.01.01',
                   'end':'2025.11.11',
                   'interval':'1d'}

custom_paramas = {**default_paramas,
                  'tickers':['2330.TW','2303.TW','2454.TW','2317.TW','2337.TW']}

custom_paramas
# Out:
# {'start': '2025.01.01',
#  'end': '2025.11.11',
#  'interval': '1d',
#  'tickers': ['2330.TW', '2303.TW', '2454.TW', '2317.TW', '2337.TW']}
